# %% [markdown]
# <a href="https://colab.research.google.com/github/jihoon0915-gif/-AI-BIGDATA-34-/blob/main/Part3/11_1_Residual_Networks_student.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-jy_fux55
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-jy_fux55
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    h1 = self.linear1(x).relu()
    h2 = self.linear2(torch.relu(h1))
    h3 = self.linear3(torch.relu(h2))
    return self.linear4(torch.relu(h3))

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.616526, train error 61.25,  val loss 1.678368, percent error 66.30
# Epoch     1, train loss 1.351254, train error 50.95,  val loss 1.471455, percent error 59.50
# Epoch     2, train loss 1.149164, train error 44.25,  val loss 1.321972, percent error 52.90
# Epoch     3, train loss 1.040063, train error 39.40,  val loss 1.297313, percent error 51.00
# Epoch     4, train loss 0.913793, train error 33.97,  val loss 1.204144, percent error 49.20
# Epoch     5, train loss 0.770513, train error 28.22,  val loss 1.207184, percent error 48.00
# Epoch     6, train loss 0.657938, train error 23.22,  val loss 1.148658, percent error 43.60
# Epoch     7, train loss 0.571537, train error 20.43,  val loss 1.189143, percent error 42.70
# Epoch     8, train loss 0.504319, train error 18.07,  val loss 1.127197, percent error 41.00
# Epoch     9, train loss 0.419594, train error 14.18,  val loss 1.146941, percent error 39.60
# Epoch    10, train loss 0.381324, train error 12.88,  val loss 1.153837, percent error 39.00
# Epoch    11, train loss 0.329895, train error 11.40,  val loss 1.207373, percent error 37.70
# Epoch    12, train loss 0.385480, train error 14.30,  val loss 1.321890, percent error 39.80
# Epoch    13, train loss 0.252842, train error 8.50,  val loss 1.158669, percent error 37.80
# Epoch    14, train loss 0.198431, train error 6.25,  val loss 1.269466, percent error 37.10
# Epoch    15, train loss 0.145908, train error 4.45,  val loss 1.268897, percent error 35.60
# Epoch    16, train loss 0.156791, train error 4.90,  val loss 1.405293, percent error 37.40
# Epoch    17, train loss 0.139295, train error 4.15,  val loss 1.423839, percent error 36.80
# Epoch    18, train loss 0.101979, train error 3.18,  val loss 1.466290, percent error 37.30
# Epoch    19, train loss 0.181217, train error 6.05,  val loss 1.737986, percent error 39.30
# Epoch    20, train loss 0.036749, train error 0.35,  val loss 1.407385, percent error 34.30
# Epoch    21, train loss 0.019016, train error 0.00,  val loss 1.431857, percent error 33.50
# Epoch    22, train loss 0.012192, train error 0.00,  val loss 1.447440, percent error 33.80
# Epoch    23, train loss 0.009625, train error 0.00,  val loss 1.476016, percent error 33.70
# Epoch    24, train loss 0.008153, train error 0.00,  val loss 1.499272, percent error 34.10
# Epoch    25, train loss 0.007231, train error 0.00,  val loss 1.517023, percent error 34.20
# Epoch    26, train loss 0.006554, train error 0.00,  val loss 1.543046, percent error 34.10
# Epoch    27, train loss 0.005997, train error 0.00,  val loss 1.556788, percent error 34.30
# Epoch    28, train loss 0.005450, train error 0.00,  val loss 1.572066, percent error 34.00
# Epoch    29, train loss 0.005138, train error 0.00,  val loss 1.583523, percent error 34.80
# Epoch    30, train loss 0.004719, train error 0.00,  val loss 1.599873, percent error 34.40
# Epoch    31, train loss 0.004425, train error 0.00,  val loss 1.609921, percent error 34.30
# Epoch    32, train loss 0.004162, train error 0.00,  val loss 1.619711, percent error 34.20
# Epoch    33, train loss 0.003939, train error 0.00,  val loss 1.634021, percent error 34.10
# Epoch    34, train loss 0.003731, train error 0.00,  val loss 1.646909, percent error 34.40
# Epoch    35, train loss 0.003551, train error 0.00,  val loss 1.654822, percent error 34.40
# Epoch    36, train loss 0.003386, train error 0.00,  val loss 1.665833, percent error 34.60
# Epoch    37, train loss 0.003236, train error 0.00,  val loss 1.674030, percent error 34.50
# Epoch    38, train loss 0.003091, train error 0.00,  val loss 1.684010, percent error 34.80
# Epoch    39, train loss 0.002964, train error 0.00,  val loss 1.690969, percent error 34.40
# Epoch    40, train loss 0.002898, train error 0.00,  val loss 1.695682, percent error 34.40
# Epoch    41, train loss 0.002841, train error 0.00,  val loss 1.699576, percent error 34.50
# Epoch    42, train loss 0.002787, train error 0.00,  val loss 1.703291, percent error 34.50
# Epoch    43, train loss 0.002735, train error 0.00,  val loss 1.707994, percent error 34.50
# Epoch    44, train loss 0.002684, train error 0.00,  val loss 1.711635, percent error 34.40
# Epoch    45, train loss 0.002636, train error 0.00,  val loss 1.715398, percent error 34.50
# Epoch    46, train loss 0.002589, train error 0.00,  val loss 1.718189, percent error 34.60
# Epoch    47, train loss 0.002545, train error 0.00,  val loss 1.723377, percent error 34.40
# Epoch    48, train loss 0.002499, train error 0.00,  val loss 1.725812, percent error 34.50
# Epoch    49, train loss 0.002458, train error 0.00,  val loss 1.729981, percent error 34.50
# Epoch    50, train loss 0.002416, train error 0.00,  val loss 1.732338, percent error 34.50
# Epoch    51, train loss 0.002377, train error 0.00,  val loss 1.736186, percent error 34.60
# Epoch    52, train loss 0.002338, train error 0.00,  val loss 1.739814, percent error 34.60
# Epoch    53, train loss 0.002300, train error 0.00,  val loss 1.743585, percent error 34.50
# Epoch    54, train loss 0.002265, train error 0.00,  val loss 1.746814, percent error 34.50
# Epoch    55, train loss 0.002229, train error 0.00,  val loss 1.751023, percent error 34.50
# Epoch    56, train loss 0.002194, train error 0.00,  val loss 1.753162, percent error 34.60
# Epoch    57, train loss 0.002162, train error 0.00,  val loss 1.757751, percent error 34.50
# Epoch    58, train loss 0.002130, train error 0.00,  val loss 1.759965, percent error 34.50
# Epoch    59, train loss 0.002098, train error 0.00,  val loss 1.764112, percent error 34.50
# Epoch    60, train loss 0.002082, train error 0.00,  val loss 1.765497, percent error 34.50
# Epoch    61, train loss 0.002067, train error 0.00,  val loss 1.766345, percent error 34.50
# Epoch    62, train loss 0.002052, train error 0.00,  val loss 1.767837, percent error 34.50
# Epoch    63, train loss 0.002037, train error 0.00,  val loss 1.769970, percent error 34.50
# Epoch    64, train loss 0.002023, train error 0.00,  val loss 1.771301, percent error 34.50
# Epoch    65, train loss 0.002009, train error 0.00,  val loss 1.773000, percent error 34.50
# Epoch    66, train loss 0.001995, train error 0.00,  val loss 1.774523, percent error 34.50
# Epoch    67, train loss 0.001981, train error 0.00,  val loss 1.776275, percent error 34.50
# Epoch    68, train loss 0.001967, train error 0.00,  val loss 1.777483, percent error 34.50
# Epoch    69, train loss 0.001954, train error 0.00,  val loss 1.779285, percent error 34.50
# Epoch    70, train loss 0.001940, train error 0.00,  val loss 1.780432, percent error 34.50
# Epoch    71, train loss 0.001927, train error 0.00,  val loss 1.781908, percent error 34.50
# Epoch    72, train loss 0.001915, train error 0.00,  val loss 1.783919, percent error 34.50
# Epoch    73, train loss 0.001902, train error 0.00,  val loss 1.785134, percent error 34.50
# Epoch    74, train loss 0.001889, train error 0.00,  val loss 1.786426, percent error 34.50
# Epoch    75, train loss 0.001877, train error 0.00,  val loss 1.787670, percent error 34.50
# Epoch    76, train loss 0.001865, train error 0.00,  val loss 1.789428, percent error 34.50
# Epoch    77, train loss 0.001852, train error 0.00,  val loss 1.790663, percent error 34.50
# Epoch    78, train loss 0.001840, train error 0.00,  val loss 1.792156, percent error 34.50
# Epoch    79, train loss 0.001829, train error 0.00,  val loss 1.793460, percent error 34.50
# Epoch    80, train loss 0.001823, train error 0.00,  val loss 1.794467, percent error 34.50
# Epoch    81, train loss 0.001817, train error 0.00,  val loss 1.794978, percent error 34.50
# Epoch    82, train loss 0.001811, train error 0.00,  val loss 1.795861, percent error 34.50
# Epoch    83, train loss 0.001805, train error 0.00,  val loss 1.796381, percent error 34.50
# Epoch    84, train loss 0.001800, train error 0.00,  val loss 1.797312, percent error 34.50
# Epoch    85, train loss 0.001794, train error 0.00,  val loss 1.798130, percent error 34.50
# Epoch    86, train loss 0.001788, train error 0.00,  val loss 1.798730, percent error 34.50
# Epoch    87, train loss 0.001783, train error 0.00,  val loss 1.799302, percent error 34.50
# Epoch    88, train loss 0.001777, train error 0.00,  val loss 1.800137, percent error 34.50
# Epoch    89, train loss 0.001772, train error 0.00,  val loss 1.800995, percent error 34.50
# Epoch    90, train loss 0.001766, train error 0.00,  val loss 1.801591, percent error 34.50
# Epoch    91, train loss 0.001761, train error 0.00,  val loss 1.802392, percent error 34.50
# Epoch    92, train loss 0.001755, train error 0.00,  val loss 1.802799, percent error 34.50
# Epoch    93, train loss 0.001750, train error 0.00,  val loss 1.803583, percent error 34.50
# Epoch    94, train loss 0.001745, train error 0.00,  val loss 1.804315, percent error 34.50
# Epoch    95, train loss 0.001739, train error 0.00,  val loss 1.805076, percent error 34.50
# Epoch    96, train loss 0.001734, train error 0.00,  val loss 1.805412, percent error 34.50
# Epoch    97, train loss 0.001729, train error 0.00,  val loss 1.806338, percent error 34.50
# Epoch    98, train loss 0.001724, train error 0.00,  val loss 1.806912, percent error 34.50
# Epoch    99, train loss 0.001718, train error 0.00,  val loss 1.807536, percent error 34.50

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
