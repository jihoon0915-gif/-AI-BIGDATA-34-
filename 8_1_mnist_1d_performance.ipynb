# %% [markdown]
# <a href="https://colab.research.google.com/github/jihoon0915-gif/-AI-BIGDATA-34-/blob/main/8_1_mnist_1d_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-j143mizx
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-j143mizx
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (2.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=fd677b98a6e7369002b6b38b1b6624def60d9d04cef340e7ef4e6a653848e193
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h77d04of/wheels/33/99/c5/794fea38f039adfbca82fd56e4a00b3e1e4533a808baee9910
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %%
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
import torch, torch.nn as nn

D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_k),
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    # TODO:
    # Initialize the parameters with He initialization
    # Replace this line (see figure 7.8 of book for help)
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
    print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.621355, train error 64.25,  test loss 1.709462, test error 70.60
# Epoch     1, train loss 1.374897, train error 52.03,  test loss 1.501676, test error 61.00
# Epoch     2, train loss 1.163609, train error 41.88,  test loss 1.317803, test error 50.50
# Epoch     3, train loss 1.051873, train error 39.28,  test loss 1.263150, test error 49.10
# Epoch     4, train loss 0.926418, train error 33.57,  test loss 1.196431, test error 45.40
# Epoch     5, train loss 0.843717, train error 29.97,  test loss 1.175791, test error 45.30
# Epoch     6, train loss 0.733162, train error 26.20,  test loss 1.131873, test error 42.10
# Epoch     7, train loss 0.699152, train error 25.65,  test loss 1.120570, test error 41.00
# Epoch     8, train loss 0.629218, train error 22.38,  test loss 1.113794, test error 39.50
# Epoch     9, train loss 0.567176, train error 20.00,  test loss 1.154320, test error 41.40
# Epoch    10, train loss 0.456610, train error 13.72,  test loss 1.061534, test error 37.80
# Epoch    11, train loss 0.411099, train error 11.90,  test loss 1.094831, test error 38.70
# Epoch    12, train loss 0.381483, train error 10.45,  test loss 1.123729, test error 39.40
# Epoch    13, train loss 0.368921, train error 10.90,  test loss 1.138032, test error 38.60
# Epoch    14, train loss 0.337928, train error 9.45,  test loss 1.151698, test error 38.00
# Epoch    15, train loss 0.304788, train error 7.68,  test loss 1.181775, test error 39.60
# Epoch    16, train loss 0.271280, train error 6.10,  test loss 1.157706, test error 38.80
# Epoch    17, train loss 0.269884, train error 6.78,  test loss 1.206488, test error 38.80
# Epoch    18, train loss 0.235103, train error 4.68,  test loss 1.216174, test error 39.00
# Epoch    19, train loss 0.221326, train error 4.28,  test loss 1.238201, test error 39.40
# Epoch    20, train loss 0.186853, train error 2.72,  test loss 1.235494, test error 38.90
# Epoch    21, train loss 0.177935, train error 2.60,  test loss 1.248126, test error 38.90
# Epoch    22, train loss 0.169662, train error 2.50,  test loss 1.277643, test error 39.00
# Epoch    23, train loss 0.160238, train error 2.12,  test loss 1.269916, test error 38.40
# Epoch    24, train loss 0.156619, train error 2.25,  test loss 1.300109, test error 38.60
# Epoch    25, train loss 0.144471, train error 1.47,  test loss 1.302837, test error 38.30
# Epoch    26, train loss 0.135867, train error 1.43,  test loss 1.319453, test error 38.60
# Epoch    27, train loss 0.129929, train error 1.18,  test loss 1.330556, test error 38.70
# Epoch    28, train loss 0.124329, train error 1.15,  test loss 1.344424, test error 39.20
# Epoch    29, train loss 0.118850, train error 0.93,  test loss 1.359924, test error 38.80
# Epoch    30, train loss 0.112363, train error 0.88,  test loss 1.364776, test error 38.90
# Epoch    31, train loss 0.109460, train error 0.78,  test loss 1.370154, test error 39.00
# Epoch    32, train loss 0.107163, train error 0.72,  test loss 1.374566, test error 38.40
# Epoch    33, train loss 0.103977, train error 0.65,  test loss 1.380502, test error 38.70
# Epoch    34, train loss 0.101961, train error 0.72,  test loss 1.391879, test error 39.10
# Epoch    35, train loss 0.099847, train error 0.57,  test loss 1.400642, test error 39.40
# Epoch    36, train loss 0.096759, train error 0.60,  test loss 1.406893, test error 39.20
# Epoch    37, train loss 0.094988, train error 0.45,  test loss 1.414660, test error 39.00
# Epoch    38, train loss 0.092724, train error 0.47,  test loss 1.417113, test error 39.00
# Epoch    39, train loss 0.090944, train error 0.43,  test loss 1.429719, test error 38.70
# Epoch    40, train loss 0.089075, train error 0.43,  test loss 1.430638, test error 39.30
# Epoch    41, train loss 0.088108, train error 0.43,  test loss 1.434224, test error 39.30
# Epoch    42, train loss 0.087283, train error 0.45,  test loss 1.437650, test error 39.10
# Epoch    43, train loss 0.086008, train error 0.30,  test loss 1.438914, test error 39.50
# Epoch    44, train loss 0.085431, train error 0.25,  test loss 1.439856, test error 38.90
# Epoch    45, train loss 0.084088, train error 0.30,  test loss 1.443910, test error 39.30
# Epoch    46, train loss 0.083412, train error 0.30,  test loss 1.446333, test error 39.30
# Epoch    47, train loss 0.082291, train error 0.25,  test loss 1.456587, test error 39.30
# Epoch    48, train loss 0.081303, train error 0.22,  test loss 1.456902, test error 39.50
# Epoch    49, train loss 0.080503, train error 0.25,  test loss 1.458928, test error 39.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
